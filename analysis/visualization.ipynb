# %% [markdown]
# # Result Analysis

# %% [markdown]
# ## Defining Parameters

# %%
from utils import ploting, PLOTABLE_CLASSES
import numpy as np
import mlflow
import pickle
import matplotlib.pyplot as plt
import os
from mpl_toolkits.axes_grid1 import make_axes_locatable

# The path to the output file
PATH = "file:///lrde/home2/rdi-2022/rhermary/update_morphonet/src/mlruns/0/9dd8f931b493403ab3a88f30301b9c6b/artifacts/outputs/001349.pickle"
MLFLOW_URI = "../mlruns"

# %%
ploting(
    uri=MLFLOW_URI,
    experiment_name="baseline",
    models=["smorphnet", "smorphnet"],
    structuring_elements=["diamondaa3", "cross3", "cross7", "diamondaa3", "complex"],
    operations=["erosion"],
    iterations=[0],
    stretch=1,
)

# %% [markdown]
# ## Model Structure

# %%
# get_keys(PATH)

# %% [markdown]
# ## Structuring Element(s)

# %%
# plot_sel(PATH)
